# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
def getFromFile(file,info):
    cap = cv2.VideoCapture(file)
    ret, frame = cap.read()
    cap.release()
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    if(info):
        print(f'The shape of the image is {frame_rgb.shape}')
    return frame_rgb

# %%
def getLimits(b,g,r,rangeWidth):
    arr = [[[b,g,r]]]
    color = np.uint8(arr)
    hsvColor = cv2.cvtColor(color, cv2.COLOR_BGR2HSV)
    lowerLimit = [hsvColor[0][0][0]-rangeWidth,40,40]
    upperLimit = [hsvColor[0][0][0]+rangeWidth,255,255]
    return [lowerLimit,upperLimit]

# %% [raw]
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
#
# def frame_diff(prev_frame, cap):
#     ret, next_frame = cap.read()
#     next_frame = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)
#     next_frame = cv2.flip(next_frame,0)
#     diff = cv2.absdiff(prev_frame, next_frame)
# #     diff = cv2.cvtColor(diff, cv2.COLOR_BGR2GRAY)
#     diff = cv2.normalize(diff, None, 0, 255, cv2.NORM_MINMAX)
#     return diff
#
# def frameCenter(frame, area):
#     # Find contours in the bw frame
# #     lims=getLimits(255,255,255,10)
# #     print(lims)
# #     lowerLimit = lims[0]
# #     upperLimit = lims[1]
#     lowerLimit=[0,0,30]
#     upperLimit = [0,0,100]
#     hsv_image =  cv2.cvtColor(frame, cv2.COLOR_GRAY2RGB)
#     hsv_image =  cv2.cvtColor(hsv_image, cv2.COLOR_RGB2HSV)
#
#     blue_regions = cv2.inRange(hsv_image, np.array(lowerLimit), np.array(upperLimit))
#
#     contours, _ = cv2.findContours(blue_regions, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# #     contours, _ = cv2.findContours(frame, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#
#     for contour in contours:
#         if cv2.contourArea(contour) > area: # Minimum contour area threshold
#             M = cv2.moments(contour)
#             if M["m00"] != 0:
#                 center_x = M["m10"] / M["m00"]
#                 center_y = M["m01"] / M["m00"]
#                 print(f"Centroid of dot: (x, y) = ({center_x:.1f}, {center_y:.1f})")
#                 return (center_x, center_y)
#     return (-1, -1)
#
#
# def ballIsMiddle(center_y, frame_height, treshold=3):
#     if center_y < frame_height/2 + treshold and center_y > frame_height/2 - treshold:
#         return True
#     else:
#         return False
#
#
#
#
# def main():
#     #open stream from camera
#     cap = cv2.VideoCapture(1)
#     #block camera from changing auto exposure
#     cap.set(cv2.CAP_PROP_AUTO_EXPOSURE, 0.25)
#     #cap.set(cv2.CAP_PROP_EXPOSURE, 0.1)
#     #block camera from changing auto white balance
#     cap.set(cv2.CAP_PROP_AUTO_WB, 0.25)
#     cap.set(cv2.CAP_PROP_WB_TEMPERATURE, 0.01)
#
#     #create window
#     cv2.namedWindow('frame', cv2.WINDOW_NORMAL)
#
#     #get frame sizes
#     frame_width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
#     frame_height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
#
#     #when q is pressed, quit
#     while True:
#         ret, frame = cap.read()
#         #compute the absolute difference between the current frame and the next frame
#         result = frame_diff(frame, cap)
#         #find centroid of ball
#         center_x,center_y = frameCenter(result, 100)
#         #make result rgb so we can add a green circle
#         result = cv2.cvtColor(result, cv2.COLOR_GRAY2RGB)
#         #add centroid to frame as a green circle
#         cv2.circle(result, (int(center_x), int(center_y)), 10, (0, 255, 0), 1)
#
#         #if ball is in the middle draw a line across the orizontal center of the frame
#         if ballIsMiddle(center_y, frame_height):
#             cv2.line(result, (0, 240), (640, 240), (255, 0, 0), 2)
#
#
#         #show the result
#         cv2.imshow('frame', result)
#         if cv2.waitKey(1) & 0xFF == ord('q'): # press q to quit
#             cap.release()
#             cv2.destroyAllWindows()
#             break
#
#     return

# %%
main()
# Out:
# Centroid of dot: (x, y) = (491.0, 239.4)
# Centroid of dot: (x, y) = (354.8, 300.7)
# Centroid of dot: (x, y) = (355.6, 360.5)
# Centroid of dot: (x, y) = (415.5, 429.7)
# Centroid of dot: (x, y) = (415.8, 440.2)
# Centroid of dot: (x, y) = (416.3, 455.3)
# Centroid of dot: (x, y) = (497.4, 348.8)
# Centroid of dot: (x, y) = (498.9, 356.9)
# Centroid of dot: (x, y) = (448.3, 239.3)
# Centroid of dot: (x, y) = (372.2, 227.3)
# Centroid of dot: (x, y) = (445.7, 251.5)
# Centroid of dot: (x, y) = (373.8, 240.4)
# Centroid of dot: (x, y) = (375.9, 217.0)
# Centroid of dot: (x, y) = (377.8, 207.6)
# Centroid of dot: (x, y) = (482.3, 344.7)
# Centroid of dot: (x, y) = (499.3, 352.7)
# Centroid of dot: (x, y) = (493.6, 285.5)
# Centroid of dot: (x, y) = (445.7, 235.2)
# Centroid of dot: (x, y) = (383.0, 211.8)
# Centroid of dot: (x, y) = (367.5, 221.2)
# Centroid of dot: (x, y) = (377.9, 230.8)
# Centroid of dot: (x, y) = (377.1, 222.4)
# Centroid of dot: (x, y) = (544.6, 442.9)
# Centroid of dot: (x, y) = (626.3, 465.1)
# Centroid of dot: (x, y) = (629.1, 472.7)
# Centroid of dot: (x, y) = (198.9, 477.5)
# Centroid of dot: (x, y) = (404.3, 470.9)
# Centroid of dot: (x, y) = (453.7, 231.5)
# Centroid of dot: (x, y) = (401.4, 352.7)
# Centroid of dot: (x, y) = (625.6, 464.4)
# Centroid of dot: (x, y) = (557.2, 474.4)
# Centroid of dot: (x, y) = (588.2, 468.5)
# Centroid of dot: (x, y) = (500.5, 471.6)
# Centroid of dot: (x, y) = (402.7, 469.7)
# Centroid of dot: (x, y) = (407.4, 475.0)
# Centroid of dot: (x, y) = (547.2, 382.7)
# Centroid of dot: (x, y) = (402.9, 355.6)
# Centroid of dot: (x, y) = (497.9, 459.2)
# Centroid of dot: (x, y) = (204.3, 473.9)
# Centroid of dot: (x, y) = (484.1, 458.0)
# Centroid of dot: (x, y) = (623.3, 471.4)
# Centroid of dot: (x, y) = (203.9, 477.1)
# Centroid of dot: (x, y) = (325.6, 476.0)
# Centroid of dot: (x, y) = (541.1, 447.3)
# Centroid of dot: (x, y) = (416.8, 386.5)
# Centroid of dot: (x, y) = (403.5, 380.9)
# Centroid of dot: (x, y) = (613.0, 446.0)
# Centroid of dot: (x, y) = (297.3, 475.5)
# Centroid of dot: (x, y) = (431.6, 475.5)
# Centroid of dot: (x, y) = (350.6, 461.4)
# Centroid of dot: (x, y) = (370.9, 474.2)
# Centroid of dot: (x, y) = (547.8, 462.7)
# Centroid of dot: (x, y) = (569.1, 15.3)
# Centroid of dot: (x, y) = (377.9, 181.1)
# Centroid of dot: (x, y) = (375.8, 268.9)
# Centroid of dot: (x, y) = (379.7, 288.7)
# Centroid of dot: (x, y) = (433.3, 349.7)
# Centroid of dot: (x, y) = (622.7, 236.0)
# Centroid of dot: (x, y) = (628.2, 257.4)
# Centroid of dot: (x, y) = (615.1, 254.0)
# Centroid of dot: (x, y) = (628.2, 342.2)
# Centroid of dot: (x, y) = (620.9, 461.8)
# Centroid of dot: (x, y) = (603.8, 462.0)
# Centroid of dot: (x, y) = (589.1, 462.4)
# Centroid of dot: (x, y) = (565.4, 314.3)
# Centroid of dot: (x, y) = (609.8, 328.7)
# Centroid of dot: (x, y) = (625.4, 458.2)
# Centroid of dot: (x, y) = (604.1, 461.7)
# Centroid of dot: (x, y) = (581.0, 462.5)
# Centroid of dot: (x, y) = (571.0, 463.7)
# Centroid of dot: (x, y) = (332.8, 439.5)
# Centroid of dot: (x, y) = (541.2, 373.8)
# Centroid of dot: (x, y) = (527.3, 331.7)
# Centroid of dot: (x, y) = (392.4, 424.3)
# Centroid of dot: (x, y) = (396.3, 422.3)
# Centroid of dot: (x, y) = (402.2, 391.9)
# Centroid of dot: (x, y) = (406.6, 394.8)
# Centroid of dot: (x, y) = (430.1, 225.3)
# Centroid of dot: (x, y) = (420.6, 322.4)
# Centroid of dot: (x, y) = (431.8, 338.0)
# Centroid of dot: (x, y) = (395.7, 394.9)
# Centroid of dot: (x, y) = (405.6, 388.9)
# Centroid of dot: (x, y) = (413.8, 427.0)
# Centroid of dot: (x, y) = (261.7, 453.8)
# Centroid of dot: (x, y) = (251.7, 455.6)
# Centroid of dot: (x, y) = (271.8, 371.3)
# Centroid of dot: (x, y) = (189.0, 461.6)
# Centroid of dot: (x, y) = (264.7, 449.9)
# Centroid of dot: (x, y) = (245.3, 444.5)
# Centroid of dot: (x, y) = (237.1, 445.4)
# Centroid of dot: (x, y) = (167.7, 340.3)
# Centroid of dot: (x, y) = (99.8, 348.4)
# Centroid of dot: (x, y) = (98.9, 346.5)
# Centroid of dot: (x, y) = (104.6, 344.6)
# Centroid of dot: (x, y) = (98.9, 351.8)
# Centroid of dot: (x, y) = (81.1, 349.7)
# Centroid of dot: (x, y) = (5.2, 330.1)
# Centroid of dot: (x, y) = (12.3, 245.2)
# Centroid of dot: (x, y) = (26.7, 239.0)
# Centroid of dot: (x, y) = (18.6, 245.3)
# Centroid of dot: (x, y) = (14.2, 337.4)
# Centroid of dot: (x, y) = (3.0, 353.5)
# Centroid of dot: (x, y) = (9.3, 325.4)
# Centroid of dot: (x, y) = (2.8, 355.9)
# Centroid of dot: (x, y) = (497.3, 346.9)
# Centroid of dot: (x, y) = (305.7, 164.6)
# Centroid of dot: (x, y) = (472.0, 406.4)
# Centroid of dot: (x, y) = (498.2, 358.1)
# Centroid of dot: (x, y) = (492.3, 273.6)
# Centroid of dot: (x, y) = (496.2, 341.4)
# Centroid of dot: (x, y) = (294.9, 424.1)
# Centroid of dot: (x, y) = (297.3, 392.8)
# Centroid of dot: (x, y) = (300.4, 369.4)
# Centroid of dot: (x, y) = (301.9, 387.7)
# Centroid of dot: (x, y) = (304.3, 356.8)
# Centroid of dot: (x, y) = (309.1, 431.3)
# Centroid of dot: (x, y) = (629.9, 349.0)
# Centroid of dot: (x, y) = (620.0, 459.0)
# Centroid of dot: (x, y) = (610.0, 457.1)
# Centroid of dot: (x, y) = (591.4, 458.2)
# Centroid of dot: (x, y) = (586.0, 437.7)
# Centroid of dot: (x, y) = (630.1, 440.7)
# Centroid of dot: (x, y) = (545.9, 459.9)
# Centroid of dot: (x, y) = (536.7, 458.2)
# Centroid of dot: (x, y) = (607.6, 451.0)
# Centroid of dot: (x, y) = (573.3, 447.0)
# Centroid of dot: (x, y) = (563.9, 442.7)
# Centroid of dot: (x, y) = (542.9, 442.7)
# Centroid of dot: (x, y) = (540.4, 446.1)
# Centroid of dot: (x, y) = (540.9, 440.8)
# Centroid of dot: (x, y) = (549.0, 388.9)
# Centroid of dot: (x, y) = (537.7, 387.3)
# Centroid of dot: (x, y) = (527.9, 384.2)
# Centroid of dot: (x, y) = (296.7, 425.8)
# Centroid of dot: (x, y) = (302.3, 369.7)
# Centroid of dot: (x, y) = (308.8, 446.6)
# Centroid of dot: (x, y) = (620.2, 434.2)
# Centroid of dot: (x, y) = (305.0, 465.0)
# Centroid of dot: (x, y) = (605.4, 428.4)
# Centroid of dot: (x, y) = (320.2, 372.7)
# Centroid of dot: (x, y) = (546.5, 450.1)
# Centroid of dot: (x, y) = (404.5, 461.4)
# Centroid of dot: (x, y) = (405.1, 432.8)
# Centroid of dot: (x, y) = (426.8, 437.4)
# Centroid of dot: (x, y) = (267.9, 447.4)
# Centroid of dot: (x, y) = (428.7, 471.1)
# Centroid of dot: (x, y) = (444.4, 469.4)
# Centroid of dot: (x, y) = (458.3, 467.5)
# Centroid of dot: (x, y) = (204.8, 458.0)
# Centroid of dot: (x, y) = (240.9, 451.5)
# Centroid of dot: (x, y) = (199.8, 457.6)
# Centroid of dot: (x, y) = (136.3, 359.4)
# Centroid of dot: (x, y) = (103.2, 292.3)
# Centroid of dot: (x, y) = (95.1, 352.5)
# Centroid of dot: (x, y) = (58.8, 343.9)
# Centroid of dot: (x, y) = (8.5, 347.4)
# Centroid of dot: (x, y) = (5.4, 350.7)
# Centroid of dot: (x, y) = (16.0, 317.7)
# Centroid of dot: (x, y) = (629.8, 453.3)
# Centroid of dot: (x, y) = (593.2, 247.2)
# Centroid of dot: (x, y) = (480.9, 48.1)
# Centroid of dot: (x, y) = (375.3, 185.2)
# Centroid of dot: (x, y) = (440.5, 223.1)
# Centroid of dot: (x, y) = (72.6, 102.3)
# Centroid of dot: (x, y) = (8.3, 354.9)
# Centroid of dot: (x, y) = (102.7, 406.1)
# Centroid of dot: (x, y) = (322.5, 466.1)
# Centroid of dot: (x, y) = (303.5, 464.0)
# Centroid of dot: (x, y) = (455.1, 461.1)
# Centroid of dot: (x, y) = (530.2, 475.1)
# Centroid of dot: (x, y) = (78.7, 441.3)
# Centroid of dot: (x, y) = (213.7, 464.0)
# Centroid of dot: (x, y) = (504.1, 475.9)
# Centroid of dot: (x, y) = (495.6, 453.1)
# Centroid of dot: (x, y) = (370.6, 464.6)
# Centroid of dot: (x, y) = (368.4, 457.0)
# Centroid of dot: (x, y) = (214.9, 462.8)
# Centroid of dot: (x, y) = (617.3, 438.9)
# Centroid of dot: (x, y) = (347.5, 465.5)
# Centroid of dot: (x, y) = (303.4, 458.8)
# Centroid of dot: (x, y) = (43.7, 470.5)
# Centroid of dot: (x, y) = (57.3, 449.8)
# Centroid of dot: (x, y) = (322.3, 471.1)
# Centroid of dot: (x, y) = (430.1, 449.8)
# Centroid of dot: (x, y) = (143.0, 473.8)
# Centroid of dot: (x, y) = (276.8, 468.1)
# Centroid of dot: (x, y) = (550.1, 459.6)
# Centroid of dot: (x, y) = (547.7, 417.2)
# Centroid of dot: (x, y) = (233.6, 429.0)
# Centroid of dot: (x, y) = (214.0, 413.5)
# Centroid of dot: (x, y) = (504.7, 423.1)
# Centroid of dot: (x, y) = (215.9, 414.5)
# Centroid of dot: (x, y) = (403.3, 405.2)
# Centroid of dot: (x, y) = (329.7, 472.0)
# Centroid of dot: (x, y) = (327.9, 474.4)
# Centroid of dot: (x, y) = (376.8, 458.8)
# Centroid of dot: (x, y) = (403.9, 453.9)
# Centroid of dot: (x, y) = (570.9, 437.6)
# Centroid of dot: (x, y) = (548.2, 452.3)
# Centroid of dot: (x, y) = (334.7, 466.4)
# Centroid of dot: (x, y) = (331.2, 460.0)
# Centroid of dot: (x, y) = (492.6, 458.2)
# Centroid of dot: (x, y) = (257.4, 464.5)
# Centroid of dot: (x, y) = (146.4, 461.0)
# Centroid of dot: (x, y) = (37.0, 467.7)
# Centroid of dot: (x, y) = (48.5, 473.0)
# Centroid of dot: (x, y) = (161.3, 476.0)
# Centroid of dot: (x, y) = (8.5, 405.1)
# Centroid of dot: (x, y) = (57.2, 416.2)
# Centroid of dot: (x, y) = (287.6, 454.5)
# Centroid of dot: (x, y) = (40.3, 415.4)
# Centroid of dot: (x, y) = (272.3, 461.9)
# Centroid of dot: (x, y) = (243.6, 465.6)
# Centroid of dot: (x, y) = (444.2, 445.8)
# Centroid of dot: (x, y) = (276.3, 474.3)
# Centroid of dot: (x, y) = (293.6, 456.7)
# Centroid of dot: (x, y) = (383.8, 224.5)
# Centroid of dot: (x, y) = (69.5, 289.3)
# Centroid of dot: (x, y) = (12.8, 149.2)
# Centroid of dot: (x, y) = (149.3, 26.4)
# Centroid of dot: (x, y) = (388.1, 187.1)
# Centroid of dot: (x, y) = (401.1, 288.9)
# Centroid of dot: (x, y) = (607.9, 15.1)
# Centroid of dot: (x, y) = (557.7, 446.9)
# Centroid of dot: (x, y) = (268.3, 465.9)
# Centroid of dot: (x, y) = (313.2, 473.8)
# Centroid of dot: (x, y) = (304.5, 473.2)
# Centroid of dot: (x, y) = (356.6, 472.9)
# Centroid of dot: (x, y) = (352.1, 463.4)
# Centroid of dot: (x, y) = (489.1, 469.2)
# Centroid of dot: (x, y) = (114.5, 454.6)
# Centroid of dot: (x, y) = (323.3, 468.6)
# Centroid of dot: (x, y) = (303.5, 465.4)
# Centroid of dot: (x, y) = (52.0, 449.6)
# Centroid of dot: (x, y) = (170.6, 468.8)
# Centroid of dot: (x, y) = (336.9, 473.7)
# Centroid of dot: (x, y) = (322.8, 466.3)
# Centroid of dot: (x, y) = (414.0, 471.3)
# Centroid of dot: (x, y) = (229.0, 471.0)
# Centroid of dot: (x, y) = (468.4, 476.6)
# Centroid of dot: (x, y) = (404.8, 472.1)
# Centroid of dot: (x, y) = (187.7, 476.5)
# Centroid of dot: (x, y) = (19.1, 451.1)
# Centroid of dot: (x, y) = (43.2, 446.7)
# Centroid of dot: (x, y) = (59.1, 448.4)
# Centroid of dot: (x, y) = (60.6, 428.2)
# Centroid of dot: (x, y) = (84.6, 392.2)
# Centroid of dot: (x, y) = (588.2, 359.2)
# Centroid of dot: (x, y) = (322.5, 425.1)
# Centroid of dot: (x, y) = (54.4, 422.8)
# Centroid of dot: (x, y) = (162.7, 463.5)
# Centroid of dot: (x, y) = (150.0, 471.6)
# Centroid of dot: (x, y) = (39.2, 425.9)
# Centroid of dot: (x, y) = (34.8, 453.4)
# Centroid of dot: (x, y) = (25.2, 446.2)
# Centroid of dot: (x, y) = (11.4, 448.1)
# Centroid of dot: (x, y) = (4.7, 453.2)
# Centroid of dot: (x, y) = (37.9, 416.8)
# Centroid of dot: (x, y) = (30.5, 473.7)
# Centroid of dot: (x, y) = (314.1, 455.9)
# Centroid of dot: (x, y) = (327.7, 475.6)
# Centroid of dot: (x, y) = (14.2, 473.4)
# Centroid of dot: (x, y) = (160.4, 473.7)
# Centroid of dot: (x, y) = (17.8, 440.7)
# Centroid of dot: (x, y) = (184.9, 477.0)
# Centroid of dot: (x, y) = (324.7, 474.1)
# Centroid of dot: (x, y) = (354.2, 471.7)
# Centroid of dot: (x, y) = (551.2, 413.7)
# Centroid of dot: (x, y) = (14.6, 413.9)
# Centroid of dot: (x, y) = (37.4, 454.3)
# Centroid of dot: (x, y) = (28.5, 449.5)
# Centroid of dot: (x, y) = (81.7, 470.1)
# Centroid of dot: (x, y) = (209.5, 475.1)
# Centroid of dot: (x, y) = (317.9, 463.9)
# Centroid of dot: (x, y) = (343.6, 453.9)
# Centroid of dot: (x, y) = (356.3, 465.6)
# Centroid of dot: (x, y) = (364.0, 467.8)
# Centroid of dot: (x, y) = (349.5, 468.1)
# Centroid of dot: (x, y) = (246.3, 448.5)
# Centroid of dot: (x, y) = (185.3, 468.7)
# Centroid of dot: (x, y) = (181.5, 463.4)
# Centroid of dot: (x, y) = (186.6, 454.2)
# Centroid of dot: (x, y) = (168.4, 436.8)
# Centroid of dot: (x, y) = (139.0, 33.1)
# Centroid of dot: (x, y) = (301.6, 470.3)
# Centroid of dot: (x, y) = (184.7, 451.2)
# Centroid of dot: (x, y) = (180.2, 460.4)
# Centroid of dot: (x, y) = (243.3, 454.7)
# Centroid of dot: (x, y) = (268.8, 445.0)
# Centroid of dot: (x, y) = (43.5, 454.1)
# Centroid of dot: (x, y) = (63.4, 447.0)
# Centroid of dot: (x, y) = (549.2, 470.4)
# Centroid of dot: (x, y) = (330.1, 474.1)
# Centroid of dot: (x, y) = (362.5, 447.4)
# Centroid of dot: (x, y) = (412.1, 462.9)
# Centroid of dot: (x, y) = (452.2, 445.4)
# Centroid of dot: (x, y) = (109.9, 450.0)
# Centroid of dot: (x, y) = (429.1, 474.0)
# Centroid of dot: (x, y) = (206.3, 464.0)
# Centroid of dot: (x, y) = (400.4, 472.6)
# Centroid of dot: (x, y) = (405.1, 453.4)
# Centroid of dot: (x, y) = (374.9, 456.9)
# Centroid of dot: (x, y) = (488.5, 468.5)
# Centroid of dot: (x, y) = (324.2, 434.9)
# Centroid of dot: (x, y) = (357.5, 472.9)
# Centroid of dot: (x, y) = (358.4, 459.9)
# Centroid of dot: (x, y) = (349.7, 455.1)
# Centroid of dot: (x, y) = (355.2, 442.0)
# Centroid of dot: (x, y) = (269.0, 413.5)
# Centroid of dot: (x, y) = (150.7, 343.5)
# Centroid of dot: (x, y) = (477.2, 377.3)
# Centroid of dot: (x, y) = (139.9, 341.2)
# Centroid of dot: (x, y) = (449.7, 288.1)
# Centroid of dot: (x, y) = (208.4, 355.1)
# Centroid of dot: (x, y) = (249.0, 414.7)
# Centroid of dot: (x, y) = (243.5, 372.7)
# Centroid of dot: (x, y) = (352.0, 461.8)
# Centroid of dot: (x, y) = (359.8, 444.2)
# Centroid of dot: (x, y) = (357.4, 438.5)
# Centroid of dot: (x, y) = (207.5, 345.2)
# Centroid of dot: (x, y) = (238.8, 118.4)
# Centroid of dot: (x, y) = (379.8, 174.3)
# Centroid of dot: (x, y) = (386.2, 205.7)
# Centroid of dot: (x, y) = (540.2, 86.4)
# Centroid of dot: (x, y) = (322.3, 471.4)
# Centroid of dot: (x, y) = (605.8, 470.9)
# Centroid of dot: (x, y) = (390.2, 469.4)
# Centroid of dot: (x, y) = (622.7, 440.4)
# Centroid of dot: (x, y) = (235.7, 454.2)
# Centroid of dot: (x, y) = (116.4, 413.9)
# Centroid of dot: (x, y) = (615.4, 454.3)
# Centroid of dot: (x, y) = (276.8, 459.1)
# Centroid of dot: (x, y) = (248.8, 438.6)
# Centroid of dot: (x, y) = (614.6, 458.3)
# Centroid of dot: (x, y) = (572.3, 473.7)
# Centroid of dot: (x, y) = (244.8, 450.5)
# Centroid of dot: (x, y) = (460.7, 467.4)
# Centroid of dot: (x, y) = (302.0, 455.9)
# Centroid of dot: (x, y) = (300.7, 458.0)
# Centroid of dot: (x, y) = (302.2, 387.2)
# Centroid of dot: (x, y) = (293.6, 399.5)
# Centroid of dot: (x, y) = (288.3, 415.3)
# Centroid of dot: (x, y) = (439.5, 224.2)
# Centroid of dot: (x, y) = (538.9, 368.5)
# Centroid of dot: (x, y) = (301.9, 465.0)
# Centroid of dot: (x, y) = (478.3, 436.8)
# Centroid of dot: (x, y) = (632.6, 468.3)
# Centroid of dot: (x, y) = (461.5, 466.4)
# Centroid of dot: (x, y) = (213.8, 454.7)
# Centroid of dot: (x, y) = (388.5, 468.0)
# Centroid of dot: (x, y) = (214.1, 454.0)
# Centroid of dot: (x, y) = (548.3, 457.2)
# Centroid of dot: (x, y) = (112.8, 464.2)
# Centroid of dot: (x, y) = (106.8, 463.4)
# Centroid of dot: (x, y) = (237.9, 465.8)
# Centroid of dot: (x, y) = (192.8, 470.6)
# Centroid of dot: (x, y) = (302.5, 468.1)
# Centroid of dot: (x, y) = (187.6, 458.3)
# Centroid of dot: (x, y) = (397.8, 455.0)
# Centroid of dot: (x, y) = (178.5, 468.9)
# Centroid of dot: (x, y) = (56.6, 407.0)
# Centroid of dot: (x, y) = (292.6, 387.0)
# Centroid of dot: (x, y) = (172.0, 445.7)
# Centroid of dot: (x, y) = (267.4, 384.8)
# Centroid of dot: (x, y) = (325.6, 442.7)
# Centroid of dot: (x, y) = (121.1, 296.4)
# Centroid of dot: (x, y) = (322.5, 437.7)
# Centroid of dot: (x, y) = (165.9, 417.1)
# Centroid of dot: (x, y) = (368.1, 460.5)
# Centroid of dot: (x, y) = (372.5, 434.7)
# Centroid of dot: (x, y) = (241.6, 448.9)
# Centroid of dot: (x, y) = (325.3, 471.7)
# Centroid of dot: (x, y) = (239.1, 449.6)
# Centroid of dot: (x, y) = (174.2, 430.0)
# Centroid of dot: (x, y) = (547.7, 442.4)
# Centroid of dot: (x, y) = (356.0, 458.0)
# Centroid of dot: (x, y) = (498.9, 456.8)
# Centroid of dot: (x, y) = (310.7, 448.8)
# Centroid of dot: (x, y) = (426.5, 410.5)
# Centroid of dot: (x, y) = (143.6, 230.0)
# Centroid of dot: (x, y) = (279.5, 362.9)
# Centroid of dot: (x, y) = (281.6, 353.3)
# Centroid of dot: (x, y) = (286.5, 343.1)
# Centroid of dot: (x, y) = (269.6, 362.4)
# Centroid of dot: (x, y) = (367.2, 330.9)
# Centroid of dot: (x, y) = (213.6, 333.6)
# Centroid of dot: (x, y) = (222.7, 317.8)
# Centroid of dot: (x, y) = (491.3, 122.0)
# Centroid of dot: (x, y) = (253.8, 261.9)
# Centroid of dot: (x, y) = (411.5, 369.6)
# Centroid of dot: (x, y) = (240.5, 351.9)
# Centroid of dot: (x, y) = (258.6, 369.0)
# Centroid of dot: (x, y) = (466.7, 368.6)
# Centroid of dot: (x, y) = (270.6, 388.9)
# Centroid of dot: (x, y) = (282.2, 388.9)
# Centroid of dot: (x, y) = (543.5, 301.9)
# Centroid of dot: (x, y) = (251.1, 386.0)
# Centroid of dot: (x, y) = (347.2, 360.0)
# Centroid of dot: (x, y) = (323.1, 395.9)
# Centroid of dot: (x, y) = (361.2, 384.1)
# Centroid of dot: (x, y) = (343.7, 409.3)
# Centroid of dot: (x, y) = (357.0, 394.0)
# Centroid of dot: (x, y) = (359.0, 375.2)
# Centroid of dot: (x, y) = (403.2, 369.8)
# Centroid of dot: (x, y) = (368.6, 351.1)
# Centroid of dot: (x, y) = (543.3, 313.9)
# Centroid of dot: (x, y) = (470.1, 246.6)
# Centroid of dot: (x, y) = (451.5, 262.4)
# Centroid of dot: (x, y) = (445.9, 274.8)
# Centroid of dot: (x, y) = (507.3, 299.7)
# Centroid of dot: (x, y) = (254.0, 211.2)
# Centroid of dot: (x, y) = (390.2, 18.8)
# Centroid of dot: (x, y) = (377.3, 207.5)
# Centroid of dot: (x, y) = (327.1, 7.1)
# Centroid of dot: (x, y) = (4.7, 213.9)
# Centroid of dot: (x, y) = (75.7, 472.6)
# Centroid of dot: (x, y) = (70.5, 472.8)
# Centroid of dot: (x, y) = (125.0, 469.3)
# Centroid of dot: (x, y) = (383.7, 467.8)
# Centroid of dot: (x, y) = (633.9, 472.2)
# Centroid of dot: (x, y) = (426.6, 469.8)
# Centroid of dot: (x, y) = (301.1, 368.2)
# Centroid of dot: (x, y) = (434.7, 456.2)
# Centroid of dot: (x, y) = (205.4, 448.7)
# Centroid of dot: (x, y) = (35.1, 412.2)
# Centroid of dot: (x, y) = (624.7, 454.8)
# Centroid of dot: (x, y) = (368.9, 447.6)
# Centroid of dot: (x, y) = (142.5, 453.3)
# Centroid of dot: (x, y) = (425.0, 416.8)
# Centroid of dot: (x, y) = (604.8, 435.4)
# Centroid of dot: (x, y) = (131.1, 461.1)
# Centroid of dot: (x, y) = (368.2, 468.8)
# Centroid of dot: (x, y) = (625.4, 463.1)
# Centroid of dot: (x, y) = (372.2, 465.9)
# Centroid of dot: (x, y) = (622.3, 454.9)
# Centroid of dot: (x, y) = (187.0, 420.1)
# Centroid of dot: (x, y) = (48.5, 449.2)
# Centroid of dot: (x, y) = (513.0, 469.2)
# Centroid of dot: (x, y) = (506.5, 462.3)
# Centroid of dot: (x, y) = (76.8, 461.1)
# Centroid of dot: (x, y) = (505.2, 460.2)
# Centroid of dot: (x, y) = (303.1, 436.6)
# Centroid of dot: (x, y) = (300.8, 453.6)
# Centroid of dot: (x, y) = (539.6, 457.3)
# Centroid of dot: (x, y) = (492.4, 436.5)
# Centroid of dot: (x, y) = (300.5, 379.3)
# Centroid of dot: (x, y) = (345.4, 365.2)
# Centroid of dot: (x, y) = (528.7, 368.6)
# Centroid of dot: (x, y) = (348.5, 352.9)
# Centroid of dot: (x, y) = (284.7, 331.8)
# Centroid of dot: (x, y) = (495.8, 366.8)
# Centroid of dot: (x, y) = (547.3, 369.4)
# Centroid of dot: (x, y) = (545.3, 374.7)
# Centroid of dot: (x, y) = (554.3, 363.5)
# Centroid of dot: (x, y) = (475.9, 342.8)
# Centroid of dot: (x, y) = (467.4, 342.7)
# Centroid of dot: (x, y) = (584.8, 323.6)
# Centroid of dot: (x, y) = (283.2, 341.7)
# Centroid of dot: (x, y) = (571.2, 328.6)
# Centroid of dot: (x, y) = (576.3, 329.0)
# Centroid of dot: (x, y) = (322.2, 349.2)
# Centroid of dot: (x, y) = (562.6, 315.7)
# Centroid of dot: (x, y) = (547.3, 329.5)
# Centroid of dot: (x, y) = (546.2, 336.3)
# Centroid of dot: (x, y) = (546.1, 324.9)
# Centroid of dot: (x, y) = (546.0, 320.4)
# Centroid of dot: (x, y) = (555.0, 321.8)
# Centroid of dot: (x, y) = (295.7, 351.4)
# Centroid of dot: (x, y) = (573.9, 322.6)
# Centroid of dot: (x, y) = (580.5, 320.2)
# Centroid of dot: (x, y) = (585.5, 319.6)
# Centroid of dot: (x, y) = (478.9, 348.8)
# Centroid of dot: (x, y) = (568.4, 310.8)
# Centroid of dot: (x, y) = (394.8, 87.6)
# Centroid of dot: (x, y) = (382.3, 187.7)
# Centroid of dot: (x, y) = (365.5, 180.1)
# Centroid of dot: (x, y) = (477.2, 244.7)
# Centroid of dot: (x, y) = (477.2, 244.7)
# Centroid of dot: (x, y) = (36.5, 270.8)
# Centroid of dot: (x, y) = (9.5, 345.4)
# Centroid of dot: (x, y) = (21.5, 346.5)
# Centroid of dot: (x, y) = (46.7, 351.6)
# Centroid of dot: (x, y) = (193.5, 455.2)
# Centroid of dot: (x, y) = (227.5, 448.4)
# Centroid of dot: (x, y) = (467.9, 411.0)
# Centroid of dot: (x, y) = (187.5, 458.5)
# Centroid of dot: (x, y) = (433.3, 451.5)
# Centroid of dot: (x, y) = (437.5, 462.9)
# Centroid of dot: (x, y) = (448.9, 454.6)
# Centroid of dot: (x, y) = (392.3, 425.4)
# Centroid of dot: (x, y) = (344.0, 458.1)
# Centroid of dot: (x, y) = (570.4, 462.1)
# Centroid of dot: (x, y) = (341.1, 464.6)
# Centroid of dot: (x, y) = (571.8, 424.9)
# Centroid of dot: (x, y) = (575.7, 379.9)
# Centroid of dot: (x, y) = (307.8, 446.4)
# Centroid of dot: (x, y) = (305.4, 422.9)
# Centroid of dot: (x, y) = (616.8, 400.1)
# Centroid of dot: (x, y) = (307.0, 440.6)
# Centroid of dot: (x, y) = (301.0, 427.0)
# Centroid of dot: (x, y) = (449.7, 272.7)

# %% [markdown]
# ## NOTE
# --Per un immagine in scala di grigi i singoli elementi dell'array sono le righe di pixel del singolo frame
# --Qui si prova a individuare una fascia centrale per cui sommare tutti i valori della fasica, che dovrebbero registrare un cambiamento al passaggio della pallina

# %%
cap = cv2.VideoCapture("palla grande.mp4")
# corners = [[200, 0], [200, 1280], [500, 1280], [500, 0]]
n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
# frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
# fps = cap.get(cv2.CAP_PROP_FPS)
    
# outfilename = "blackwhite.mp4"   

# fourcc = cv2.VideoWriter_fourcc(*'XVID')
# out = cv2.VideoWriter(outfilename, fourcc, fps, (frame_width, frame_height))

plt.axis([0,780,0,1280])
maxi = 0
max_index = 0
img = []
for frame_index in range(40, math.floor(n_frames/2)):
    ret, frame = cap.read()
    frame = cv2.flip(frame,0)
    frame = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    result = frame_diff(frame, cap)
    tot = 0
    for i in range(600,680):
        tot+=sum(result[i])
    if(tot>maxi):
        maxi=tot
        max_index = frame_index
        img = result
    print(f"frame:{frame_index},count: {tot}")
#     out.write(result)
# out.release()
print(f"max:{maxi}, max_index:{max_index}")
plt.imshow(img)
cap.release()
# Out:
# frame:40,count: 210326
# frame:41,count: 379872
# frame:42,count: 261022
# frame:43,count: 187299
# frame:44,count: 93378
# frame:45,count: 444129
# frame:46,count: 167119
# frame:47,count: 264490
# frame:48,count: 442581
# frame:49,count: 265230
# frame:50,count: 450461
# frame:51,count: 458176
# frame:52,count: 308826
# frame:53,count: 192539
# frame:54,count: 334344
# frame:55,count: 521014
# frame:56,count: 425988
# frame:57,count: 346586
# frame:58,count: 555446
# frame:59,count: 233983
# frame:60,count: 383365
# frame:61,count: 321039
# frame:62,count: 167137
# frame:63,count: 344441
# frame:64,count: 183879
# frame:65,count: 376437
# frame:66,count: 245536
# frame:67,count: 225655
# frame:68,count: 239354
# frame:69,count: 314597
# frame:70,count: 441120
# frame:71,count: 433757
# frame:72,count: 485943
# frame:73,count: 475133
# frame:74,count: 218524
# frame:75,count: 431191
# frame:76,count: 704575
# frame:77,count: 437799
# frame:78,count: 699606
# frame:79,count: 290804
# frame:80,count: 619655
# frame:81,count: 279236
# frame:82,count: 371844
# frame:83,count: 486956
# frame:84,count: 270266
# frame:85,count: 191957
# frame:86,count: 289197
# frame:87,count: 404365
# frame:88,count: 135915
# frame:89,count: 262567
# frame:90,count: 56576
# frame:91,count: 165211
# frame:92,count: 156005
# frame:93,count: 352623
# frame:94,count: 350417
# frame:95,count: 169655
# max:704575, max_index:76

# %%
def getFrame(file,num):
    cap = cv2.VideoCapture(file)
    n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f'The video contains {n_frames} frames')
    if(num>=n_frames):
        print("FRAME OUT OF INDEX")
        return -1
    else:
        cap.set(cv2.CAP_PROP_POS_FRAMES, num)
        ret, frame = cap.read()
        cap.release()
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        return frame_rgb

# %%
plt.imshow(getFrame("palla grande.mp4",120))
# Out:
# The video contains 192 frames

# %%
import math
